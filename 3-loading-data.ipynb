# %%
# %matplotlib inline
# %load_ext fireducks.pandas
import pandas as pd

# %%
df = pd.read_excel("./datasets/complete-2020.xlsx",index_col=0)

# %% [markdown]
# No todos los set de datos incluyen la primera columna como un indice, por lo que si no lo tiene se puede omitir la primera linea de lectura de datos.

# %%
df.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>day</th>
#       <th>views</th>
#       <th>redViews</th>
#       <th>comments</th>
#       <th>likes</th>
#       <th>dislikes</th>
#       <th>videosAddedToPlaylists</th>
#       <th>videosRemovedFromPlaylists</th>
#       <th>shares</th>
#       <th>estimatedMinutesWatched</th>
#       <th>...</th>
#       <th>subscribersGained</th>
#       <th>subscribersLost</th>
#       <th>estimatedRevenue</th>
#       <th>estimatedAdRevenue</th>
#       <th>grossRevenue</th>
#       <th>estimatedRedPartnerRevenue</th>
#       <th>monetizedPlaybacks</th>
#       <th>playbackBasedCpm</th>
#       <th>adImpressions</th>
# ...

# %%
df.tail()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>day</th>
#       <th>views</th>
#       <th>redViews</th>
#       <th>comments</th>
#       <th>likes</th>
#       <th>dislikes</th>
#       <th>videosAddedToPlaylists</th>
#       <th>videosRemovedFromPlaylists</th>
#       <th>shares</th>
#       <th>estimatedMinutesWatched</th>
#       <th>...</th>
#       <th>subscribersGained</th>
#       <th>subscribersLost</th>
#       <th>estimatedRevenue</th>
#       <th>estimatedAdRevenue</th>
#       <th>grossRevenue</th>
#       <th>estimatedRedPartnerRevenue</th>
#       <th>monetizedPlaybacks</th>
#       <th>playbackBasedCpm</th>
#       <th>adImpressions</th>
# ...

# %%
df
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>day</th>
#       <th>views</th>
#       <th>redViews</th>
#       <th>comments</th>
#       <th>likes</th>
#       <th>dislikes</th>
#       <th>videosAddedToPlaylists</th>
#       <th>videosRemovedFromPlaylists</th>
#       <th>shares</th>
#       <th>estimatedMinutesWatched</th>
#       <th>...</th>
#       <th>subscribersGained</th>
#       <th>subscribersLost</th>
#       <th>estimatedRevenue</th>
#       <th>estimatedAdRevenue</th>
#       <th>grossRevenue</th>
#       <th>estimatedRedPartnerRevenue</th>
#       <th>monetizedPlaybacks</th>
#       <th>playbackBasedCpm</th>
#       <th>adImpressions</th>
# ...

# %% [markdown]
# en la columna date el valor es un string, pero esta en formato de fecha, por lo que se puede convertir a un formato de fecha con la funcion pd.to_datetime

# %%
df["day"]
# para acceder a una columna, esto se hace de forma muy similar a un diccionario, y se puede acceder a una columna por su nombre. retorna toda la columna
# Out:
# 0      2020-01-01
# 1      2020-01-02
# 2      2020-01-03
# 3      2020-01-04
# 4      2020-01-05
#           ...
# 361    2020-12-27
# 362    2020-12-28
# 363    2020-12-29
# 364    2020-12-30
# 365    2020-12-31
# Name: day, Length: 366, dtype: object

# %%
df["day"]=pd.to_datetime(df["day"],format="%Y-%m-%d")

# %%
df.dtypes # los objetos normalmente son strings
# Out:
# day                               datetime64[ns]
# views                                      int64
# redViews                                   int64
# comments                                   int64
# likes                                      int64
# dislikes                                   int64
# videosAddedToPlaylists                     int64
# videosRemovedFromPlaylists                 int64
# shares                                     int64
# estimatedMinutesWatched                    int64
# estimatedRedMinutesWatched                 int64
# averageViewDuration                        int64
# averageViewPercentage                    float64
# annotationClickThroughRate                 int64
# annotationCloseRate                        int64
# annotationImpressions                      int64
# annotationClickableImpressions             int64
# annotationClosableImpressions              int64
# annotationClicks                           int64
# ...

# %%
df.shape # retorna la cantidad de filas y columnas, y no incluye la columna de indices
# Out:
# (366, 36)

# %%
df.to_csv("./complete-2020.csv")
