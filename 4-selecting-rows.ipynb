# %%
# %matplotlib inline
# %load_ext fireducks.pandas
import pandas as pd

# %%
df = pd.read_excel("./datasets/complete-2020.xlsx",index_col=0)
df["day"]=pd.to_datetime(df["day"],format="%Y-%m-%d")
df.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>day</th>
#       <th>views</th>
#       <th>redViews</th>
#       <th>comments</th>
#       <th>likes</th>
#       <th>dislikes</th>
#       <th>videosAddedToPlaylists</th>
#       <th>videosRemovedFromPlaylists</th>
#       <th>shares</th>
#       <th>estimatedMinutesWatched</th>
#       <th>...</th>
#       <th>subscribersGained</th>
#       <th>subscribersLost</th>
#       <th>estimatedRevenue</th>
#       <th>estimatedAdRevenue</th>
#       <th>grossRevenue</th>
#       <th>estimatedRedPartnerRevenue</th>
#       <th>monetizedPlaybacks</th>
#       <th>playbackBasedCpm</th>
#       <th>adImpressions</th>
# ...

# %%
df_slice = df[15:50]
df_slice.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>day</th>
#       <th>views</th>
#       <th>redViews</th>
#       <th>comments</th>
#       <th>likes</th>
#       <th>dislikes</th>
#       <th>videosAddedToPlaylists</th>
#       <th>videosRemovedFromPlaylists</th>
#       <th>shares</th>
#       <th>estimatedMinutesWatched</th>
#       <th>...</th>
#       <th>subscribersGained</th>
#       <th>subscribersLost</th>
#       <th>estimatedRevenue</th>
#       <th>estimatedAdRevenue</th>
#       <th>grossRevenue</th>
#       <th>estimatedRedPartnerRevenue</th>
#       <th>monetizedPlaybacks</th>
#       <th>playbackBasedCpm</th>
#       <th>adImpressions</th>
# ...

# %%
views = df["views"]
views
# Out:
# 0        38
# 1        28
# 2        16
# 3         8
# 4        18
#        ...
# 361    1338
# 362    1389
# 363    1292
# 364    1245
# 365    1125
# Name: views, Length: 366, dtype: int64

# %% [markdown]
# si quieres seleccionar un subconjunto de las columnas, puedes hacerlo de la siguiente manera:
# ```python
# df = df[['columna1', 'columna2', 'columna3']]
# ```
# tiene que ser una lista de lista, si solo quieres seleccionar una columna, puedes hacerlo de la siguiente manera:
# ```python
# df = df["columna1"]
# ```
# solo puede ser una lista, no se puede con un iterable

# %%
df_min = df[["views","comments","likes"]]
df_min.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>views</th>
#       <th>comments</th>
#       <th>likes</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>38</td>
#       <td>1</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>28</td>
#       <td>0</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>16</td>
#       <td>1</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>8</td>
#       <td>0</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>18</td>
#       <td>0</td>
#       <td>0</td>
#     </tr>
#   </tbody>
# </table>
# ...

# %%
df_section =df.iloc[5:10,1:5] #iloc is used to select rows and columns by number
#sirve para seleccionar filas y columnas por número
df_section.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>views</th>
#       <th>redViews</th>
#       <th>comments</th>
#       <th>likes</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>5</th>
#       <td>17</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>19</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>12</td>
#       <td>1</td>
#       <td>0</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>23</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#     </tr>
#     <tr>
# ...
