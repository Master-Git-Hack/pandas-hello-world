# %%
# %matplotlib inline
# %load_ext fireducks.pandas
import pandas as pd

# %%
df = pd.read_excel("./datasets/complete-2020.xlsx",index_col=0)
df["day"]=pd.to_datetime(df["day"],format="%Y-%m-%d")
df.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>day</th>
#       <th>views</th>
#       <th>redViews</th>
#       <th>comments</th>
#       <th>likes</th>
#       <th>dislikes</th>
#       <th>videosAddedToPlaylists</th>
#       <th>videosRemovedFromPlaylists</th>
#       <th>shares</th>
#       <th>estimatedMinutesWatched</th>
#       <th>...</th>
#       <th>subscribersGained</th>
#       <th>subscribersLost</th>
#       <th>estimatedRevenue</th>
#       <th>estimatedAdRevenue</th>
#       <th>grossRevenue</th>
#       <th>estimatedRedPartnerRevenue</th>
#       <th>monetizedPlaybacks</th>
#       <th>playbackBasedCpm</th>
#       <th>adImpressions</th>
# ...

# %%
df.describe()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>views</th>
#       <th>redViews</th>
#       <th>comments</th>
#       <th>likes</th>
#       <th>dislikes</th>
#       <th>videosAddedToPlaylists</th>
#       <th>videosRemovedFromPlaylists</th>
#       <th>shares</th>
#       <th>estimatedMinutesWatched</th>
#       <th>estimatedRedMinutesWatched</th>
#       <th>...</th>
#       <th>subscribersGained</th>
#       <th>subscribersLost</th>
#       <th>estimatedRevenue</th>
#       <th>estimatedAdRevenue</th>
#       <th>grossRevenue</th>
#       <th>estimatedRedPartnerRevenue</th>
#       <th>monetizedPlaybacks</th>
#       <th>playbackBasedCpm</th>
# ...

# %%
df["views"].describe()
# Out:
# count     366.000000
# mean      605.800546
# std       505.269754
# min         7.000000
# 25%        96.000000
# 50%       506.000000
# 75%      1126.750000
# max      1572.000000
# Name: views, dtype: float64

# %%
df.sort_values("views",ascending=False).head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>day</th>
#       <th>views</th>
#       <th>redViews</th>
#       <th>comments</th>
#       <th>likes</th>
#       <th>dislikes</th>
#       <th>videosAddedToPlaylists</th>
#       <th>videosRemovedFromPlaylists</th>
#       <th>shares</th>
#       <th>estimatedMinutesWatched</th>
#       <th>...</th>
#       <th>subscribersGained</th>
#       <th>subscribersLost</th>
#       <th>estimatedRevenue</th>
#       <th>estimatedAdRevenue</th>
#       <th>grossRevenue</th>
#       <th>estimatedRedPartnerRevenue</th>
#       <th>monetizedPlaybacks</th>
#       <th>playbackBasedCpm</th>
#       <th>adImpressions</th>
# ...

# %% [markdown]
# para ordenar los datos a traves de multiples columnas, se puede usar la funcion sort_values() de pandas.
# ```python
# df.sort_values(by=['col1', 'col2'], ascending=[True, False])
# ```

# %%
df.sort_values(["views","estimatedMinutesWatched"],ascending=[False,False]).head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>day</th>
#       <th>views</th>
#       <th>redViews</th>
#       <th>comments</th>
#       <th>likes</th>
#       <th>dislikes</th>
#       <th>videosAddedToPlaylists</th>
#       <th>videosRemovedFromPlaylists</th>
#       <th>shares</th>
#       <th>estimatedMinutesWatched</th>
#       <th>...</th>
#       <th>subscribersGained</th>
#       <th>subscribersLost</th>
#       <th>estimatedRevenue</th>
#       <th>estimatedAdRevenue</th>
#       <th>grossRevenue</th>
#       <th>estimatedRedPartnerRevenue</th>
#       <th>monetizedPlaybacks</th>
#       <th>playbackBasedCpm</th>
#       <th>adImpressions</th>
# ...
