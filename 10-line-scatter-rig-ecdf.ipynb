# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("./datasets/second-half-2020.csv", index_col=0)
df["day"] = pd.to_datetime(df["day"], format="%Y-%m-%d")
df.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>day</th>
#       <th>views</th>
#       <th>redViews</th>
#       <th>comments</th>
#       <th>likes</th>
#       <th>dislikes</th>
#       <th>videosAddedToPlaylists</th>
#       <th>videosRemovedFromPlaylists</th>
#       <th>shares</th>
#       <th>estimatedMinutesWatched</th>
#       <th>...</th>
#       <th>subscribersGained</th>
#       <th>subscribersLost</th>
#       <th>estimatedRevenue</th>
#       <th>estimatedAdRevenue</th>
#       <th>grossRevenue</th>
#       <th>estimatedRedPartnerRevenue</th>
#       <th>monetizedPlaybacks</th>
#       <th>playbackBasedCpm</th>
#       <th>adImpressions</th>
# ...

# %% [markdown]
# to_datetime parametros:
# - year: int
# - month: int
# - day: int
# - hour: int
# - minute: int
# - second: int
# - microsecond: int
# - nanosecond: int
# - tz: Union[str, datetime.tzinfo, None] = None
# - format: Union[str, None] = None
# - errors: str = 'raise'
# - infer_datetime_format: bool = False (se refiere a si se debe inferir el formato de la cadena de fecha y hora)
# - dayfirst: bool = False
# - yearfirst: bool = False
# - utc: bool = None
# - box: bool = True (si es True, devuelve un DataFrame si se pasa una lista de datos)
# - format: str = None
# - exact: bool = True
# - unit: str = None (si se pasa, se convierte a la unidad especificada, si no, se convierte a datetime64[ns])
# - origin: Union[str, datetime.datetime, Timestamp] = 'unix' (puede ser 'unix
# - cache: bool = True
# tipo de errores:
# - 'raise': si hay errores, se lanza un ValueError
# - 'coerce': si hay errores, se establece NaT (Not a Time)
# - 'ignore': si hay errores, se devuelve la entrada original
# - 'warn': si hay errores, se imprime un aviso y se devuelve la entrada original
# - 'default': si hay errores, se establece NaT (Not a Time)
# - 'backward': si hay errores, se establece NaT (Not a Time)
# - 'forward': si hay errores, se establece NaT (Not a Time)
# - 'quietly': si hay errores, se establece NaT (Not a Time)

# %% [markdown]
# lineplot de sns recibe de parametros:
# - x: eje x
# - y: eje y
# - data: dataframe
# - hue: color de la linea
# - style: estilo de la linea
# - markers: marcadores
# - dashes: tipo de linea
# - ci: intervalo de confianza
# - estimator: estimador
# - ax: eje
# - legend: leyenda
# - palette: paleta de colores
# - hue_order: orden de los colores
# - style_order: orden de los estilos
# - units: unidades
# - estimator: estimador
# - n_boot: numero de bootstraps(bootstrap es una tecnica de remuestreo)
# - sort: ordenar
# - err_style: estilo de errorhue="country"
# - err_kws: parametros del error
# - legend: leyenda

# %%
fig = plt.figure()
sns.lineplot(data=df, x="views", y="day",)
fig.show()
# Out:
# /home/master/.virtualenvs/Pandas-Carberra-nubz/lib/python3.12/site-packages/fireducks/pandas/generic.py:775: UserWarning: df2 = df1.copy(deep=False) might not work, when changes made in the data values of 'df2' is expected to be reflected in 'df1'. REF: https://fireducks-dev.github.io/docs/user-guide/04-compatibility/#copydeep--false
#   warnings.warn(
# 2024-09-18 12:56:11.155075: 365264 fire/lib/fire_helper.cc:24] Encountered runtime error: Array type doesn't match type of values set: timestamp[ns] vs double
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[29], line 2
#       1 fig = plt.figure()
# ----> 2 sns.lineplot(data=df[["views","day"]], x="views", y="day",)
#       3 fig.show()
#
# ...

# %%
fig = plt.figure()
sns.scatterplot(data=df, x="views", y="estimatedMinutesWatched", hue=df["dislikes"] > 0)
fig.show()
# Out:
# /home/master/.virtualenvs/Pandas-Carberra-nubz/lib/python3.12/site-packages/fireducks/pandas/generic.py:775: UserWarning: df2 = df1.copy(deep=False) might not work, when changes made in the data values of 'df2' is expected to be reflected in 'df1'. REF: https://fireducks-dev.github.io/docs/user-guide/04-compatibility/#copydeep--false
#   warnings.warn(
# /tmp/ipykernel_365264/203240642.py:3: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %%
fig = plt.figure()
sns.scatterplot(data=df, x="views", y="estimatedMinutesWatched", hue=df["dislikes"] > 0)
sns.rugplot(data=df, y="views", hue=df["dislikes"] > 0, alpha=0.5)
fig.show()
# Out:
# /home/master/.virtualenvs/Pandas-Carberra-nubz/lib/python3.12/site-packages/fireducks/pandas/generic.py:775: UserWarning: df2 = df1.copy(deep=False) might not work, when changes made in the data values of 'df2' is expected to be reflected in 'df1'. REF: https://fireducks-dev.github.io/docs/user-guide/04-compatibility/#copydeep--false
#   warnings.warn(
# /home/master/.virtualenvs/Pandas-Carberra-nubz/lib/python3.12/site-packages/fireducks/pandas/generic.py:775: UserWarning: df2 = df1.copy(deep=False) might not work, when changes made in the data values of 'df2' is expected to be reflected in 'df1'. REF: https://fireducks-dev.github.io/docs/user-guide/04-compatibility/#copydeep--false
#   warnings.warn(
# /tmp/ipykernel_365264/953779159.py:4: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %%
fig = plt.figure()
sns.ecdfplot(data=df, x="views", stat="count")
fig.show()
# Out:
# /home/master/.virtualenvs/Pandas-Carberra-nubz/lib/python3.12/site-packages/fireducks/pandas/generic.py:775: UserWarning: df2 = df1.copy(deep=False) might not work, when changes made in the data values of 'df2' is expected to be reflected in 'df1'. REF: https://fireducks-dev.github.io/docs/user-guide/04-compatibility/#copydeep--false
#   warnings.warn(
# /tmp/ipykernel_365264/3580011618.py:3: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
